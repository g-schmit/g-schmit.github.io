# %%
import pandas as pd
df = pd.read_csv('Skyrim_Weapons.csv')
df
# Out:
#                                 Name  Damage  Weight  Gold  \
# 0            Ancient Nord Battle Axe      18    22.0    28
# 1                  Daedric Battleaxe      25    27.0  2750
# 2              Dragonbone Battleaxe       26    30.0  3000
# 3               Drainblood Battleaxe      21     5.0   266
# 4                  Dwarven Battleaxe      20    23.0   300
# ..                               ...     ...     ...   ...
# 288      Exploding Steel Bolt of Ice      10     0.0     5
# 289    Exploding Steel Bolt of Shock      10     0.0     5
# 290   Exploding Dwarven Bolt of Fire      14     0.0    15
# 291    Exploding Dwarven Bolt of Ice      14     0.0    15
# 292  Exploding Dwarven Bolt of Shock      14     0.0    15
#
#                  Upgrade     Perk       Type    Category  Speed
# 0            Steel Ingot    Steel  Battleaxe  Two-Handed    NaN
# 1            Ebony Ingot  Daedric  Battleaxe  Two-Handed    NaN
# ...

# %%
df = df.dropna(subset=['Upgrade'])
df
# Out:
#                           Name  Damage  Weight  Gold              Upgrade  \
# 0      Ancient Nord Battle Axe      18    22.0    28          Steel Ingot
# 1            Daedric Battleaxe      25    27.0  2750          Ebony Ingot
# 2        Dragonbone Battleaxe       26    30.0  3000          Dragon Bone
# 4            Dwarven Battleaxe      20    23.0   300  Dwarven Metal Ingot
# 5              Ebony Battleaxe      23    26.0  1585          Ebony Ingot
# ..                         ...     ...     ...   ...                  ...
# 260                  Zephyr DG      12    10.0   670  Dwarven Metal Ingot
# 281                   Crossbow      19    14.0   120          Steel Ingot
# 282           Dwarven Crossbow      22    20.0   350  Dwarven metal ingot
# 283          Enhanced Crossbow      19    15.0   200          Steel Ingot
# 284  Enhanced Dwarven Crossbow      22    21.0   550  Dwarven metal ingot
#
#         Perk       Type    Category  Speed
# ...

# %%
df.loc[df['Type'].str.contains('Bow'), 'Type'] = None
df.dropna(subset=['Type'], inplace=True)
df
# Out:
#                         Name  Damage  Weight  Gold              Upgrade  \
# 0    Ancient Nord Battle Axe      18    22.0    28          Steel Ingot
# 1          Daedric Battleaxe      25    27.0  2750          Ebony Ingot
# 2      Dragonbone Battleaxe       26    30.0  3000          Dragon Bone
# 4          Dwarven Battleaxe      20    23.0   300  Dwarven Metal Ingot
# 5            Ebony Battleaxe      23    26.0  1585          Ebony Ingot
# ..                       ...     ...     ...   ...                  ...
# 216      Shagrol's Warhammer      21    26.0   200     Orichalcum Ingot
# 217      Stalhrim Warhammer       26    29.0  2850             Stalhrim
# 218          Steel Warhammer      20    25.0   110          Steel Ingot
# 219           The Longhammer      21    18.0    90     Orichalcum Ingot
# 220               Trollsbane      20    25.0   121          Steel Ingot
#
#         Perk       Type    Category  Speed
# 0      Steel  Battleaxe  Two-Handed    NaN
# ...

# %%
df.sample(10)
# Out:
#                                Name  Damage  Weight  Gold  \
# 91                      Ebony Sword      13    15.0   720
# 177               Stalhrim War Axe       15    16.0  1180
# 196            Nordic Greatsword DR      20    19.0   585
# 83            Dragonbane (Lvl 1-18)      10    10.0   789
# 139      The Pale Blade (Lvl 19-26)      11    15.0   667
# 31                     Ebony Dagger      10     5.0   290
# 2             Dragonbone Battleaxe       26    30.0  3000
# 16   Steel Battleaxe of Fiery Souls      18    21.0   320
# 23                     Blade of Woe      12     7.0   880
# 30                   Dwarven Dagger       7     3.5    55
#
#                  Upgrade      Perk        Type    Category  Speed
# 91           Ebony Ingot     Ebony       Sword  One-Handed    NaN
# 177             Stalhrim     Ebony     War Axe  One-Handed    NaN
# 196    Quicksilver Ingot  Advanced  Greatsword  Two-Handed    NaN
# ...

# %%
df.loc[df['Name'] == 'Ebony Sword', ['Weight', 'Damage', 'Gold']] = None

# %%
df.drop(columns={'Speed'}, inplace=True)
df.loc[df['Name'] == 'Ebony Sword']
# Out:
#            Name  Damage  Weight  Gold      Upgrade   Perk   Type    Category
# 91  Ebony Sword     NaN     NaN   NaN  Ebony Ingot  Ebony  Sword  One-Handed

# %%
df.to_csv('Skyrim_Weapons2.csv')
