# %%
import pandas as pd
df = pd.read_csv('NFL2.csv.zip')
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_30132\3812366747.py:2: DtypeWarning: Columns (26,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('NFL2.csv.zip')

# %%
# for i in df[df.GameID==2017102900].index:
#     if i%3 == 0:
#         df.iloc[i].Win_Prob = None
# df.to_csv('NFL2.csv.zip')
df[df.GameID==2017102900].sort_values("TimeSecs").set_index("TimeSecs")["ScoreDiff"].plot(figsize=(20,5))
df[df.GameID==2017102900].sort_values("TimeSecs").set_index("TimeSecs")["Win_Prob"].plot(figsize=(20,5), secondary_y = True)
# Out:
# <AxesSubplot: >
